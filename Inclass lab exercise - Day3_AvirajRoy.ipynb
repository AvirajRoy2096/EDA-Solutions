# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#aec101"> Bivariate Analysis

# %% [markdown]
# * Bivariate analysis is a statistical method that helps you study relationships (correlation) between data sets

# %% [markdown]
# ### Quantitative vs. Quantitative
#     1. Scatterplot
#     2. Line plot

# %% [markdown]
# ### Categorical vs. Quantitative
#     1. Bar chart (on summary statistics)
#     2. Grouped kernel density plots
#     3. Box plots
#     4. Violin plots

# %% [markdown]
# ### Categorical vs. Categorical
#     1. Stacked bar chart
#     2. Grouped bar chart
#     3. Segmented bar chart

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#aec101">Case study 1
#     <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#b53f05"> (Titanic Data Set)

# %% [markdown]
# ### Problem Feature:
# The sinking of the Titanic is one of the most infamous shipwrecks in history. **On April 15, 1912**, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing **1502 out of 2224** passengers and crew. That's why the name DieTanic. This is a very unforgetable disaster that no one in the world can forget.
#
# 1.  **Age** ==>> Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# 2. **Sibsp** ==>> The dataset defines family relations in this way...
#
#     a. Sibling = brother, sister, stepbrother, stepsister
#
#     b. Spouse = husband, wife (mistresses and fiancés were ignored)
#
# 3. **Parch** ==>> The dataset defines family relations in this way...
#
#     a. Parent = mother, father
#
#     b. Child = daughter, son, stepdaughter, stepson
#
#     c. Some children travelled only with a nanny, therefore parch=0 for them.
#
# 4. **Pclass** ==>> A proxy for socio-economic status (SES)
#
#     * 1st = Upper
#     * 2nd = Middle
#     * 3rd = Lower
#
# 5. **Embarked** ==>> nominal datatype
# 6. **Name** ==>> nominal datatype . It could be used in feature engineering to derive the gender from title
# 7. **Sex** ==>>  nominal datatype
# 8. **Ticket** ==>> that have no impact on the outcome variable. Thus, they will be excluded from analysis
# 9. **Cabin** ==>>  is a nominal datatype that can be used in feature engineering
# 11. **Fare** ==>>  Indicating the fare
# 12. **PassengerID ** ==>> have no impact on the outcome variable. Thus, it will be excluded from analysis
# 11. **Survival** is ==>> **[dependent variable], 0 or 1

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.1 Loading the libraries

# %%
import pandas as pd 
import numpy as np
from pandas import Series,DataFrame
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.2 import the dataset ?

# %%
train=pd.read_csv('C:\\Users\\AVIRAJ\\Downloads\\Titanictrain.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.3 How to see the size of your data?

# %%
train.shape
# Out:
# (891, 12)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.4 How to view the statistical characteristics of the data?

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.5 How to see just one column.describe()?

# %%
train['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.6 How to check the column names?

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.7 Check the Numerical Features,Categorical Features, Alphanumeric Features?

# %% [markdown]
#     * Categorical:
#     * Numerical Features:
#     * Alphanumeric Features:

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.8 Categorical vs. Quantitative

# %% [markdown]
#     * Categorical:
#     * Numerical Features:

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.8a) Create bar plot for showing Sex Vs Survived. And your Observation?

# %%
#draw a bar plot of survival by sex
sns.barplot(x=train['Sex'],y=train['Survived'])
plt.show()

#print percentages of females vs. males that survive
a=train.groupby(by=['Sex','Survived'])
m=train['Sex'].value_counts()[0]
f=train['Sex'].value_counts()[1]
b=a['Survived'].value_counts()
f_s=a['Survived'].value_counts()[1]

m_s=a['Survived'].value_counts()[3]
print('Percentage of Males survived=',round(((m_s/m)*100),2),"%")
print('Percentage of Females survived=',round(((f_s/f)*100),2),"%")
# Out:
# Percentage of Males survived= 18.89 %
# Percentage of Females survived= 74.2 %

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observation:

# %%
Percentage of Female survival is very high than the males.
Hence Male survival rate is much lower indicating their death rate is higher than females.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">1.8d) Create a bar plot Pclass Vs Survived.And your Observation?

# %%
# Create subplot
sns.barplot(y=train['Survived'],x=train['Pclass'])
plt.show()

#print percentages of 1st vs. 2nd and 3rd class
a=train.groupby(by=['Survived','Pclass'])
b=a['Survived'].count()
fc_sur=b[3]
sctc_sur=b[4]+b[5]
sur_total=b[3]+b[4]+b[5]
print('Percentage of 1st class Survivors=',round(((fc_sur/sur_total)*100),3),"%")
print('Percentage of 2nd & 3rd class combined Survivors=',round(((sctc_sur/sur_total)*100),3),"%")
# Out:
# Percentage of 1st class Survivors= 39.766 %
# Percentage of 2nd & 3rd class combined Survivors= 60.234 %

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observation:

# %%
Statistically we can see that 1st class passengers were more saved than any other Classes.
It can be seen like they were given more importance while in times of survival.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.8c) Create Bar plot for checking the both Survived vs Sex and Sex:Survived or Not. And your Observations?

# %%
#create a subplot
f,ax=plt.subplots(1,2,figsize=(15,5))
# create count plot
sns.countplot(train['Survived'],ax=ax[0])
sns.countplot(train['Sex'],ax=ax[1])
plt.show()

# %%
# create bar plot using groupby
a=train.groupby(['Survived','Sex'])
b=a['Sex'].count().unstack().plot.barh()
print(b)
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101">  Observation:

# %%
Most Survived were females rather than males.
Most people who did not survive were males which are much higher than females

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  1.8d) Create Bar plot for checking the following:
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  Number Of Passengers By Pclass &
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  Pclass:Survived vs Dead.

# %%
# create subplot plot
f,ax=plt.subplots(1,2,figsize=(15,5))
# create bar plot using groupby
train.groupby(['Survived','Pclass'])['Pclass'].count().plot(kind='bar',ax=ax[0])
ax[0].set_title('Pclass Vs Survived')
# create count plot
sns.countplot(train['Pclass'],ax=ax[1])
ax[1].set_title('Passengers by Pclass')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101">  Observation:

# %%
We observe from Fig-1 that most passengers dead were belonging to Class-3
Also the passenger count in Class-3 were the highest.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  1.8e) Create violinplot plot for checking
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">    a) Pclass vs. Age sliced by Survived
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">    b) Sex vs Age sliced by Survived. And your Observations?

# %%
# create subplot plot
f,ax=plt.subplots(1,2,figsize=(15,5))

# create violinplot plot using groupby
a=train.groupby(['Pclass','Age']).sum()
a.reset_index(inplace=True)
sns.violinplot(x='Pclass',y='Age',hue='Survived',data=train,ax=ax[0])
sns.violinplot(x='Sex',y='Age',hue='Survived',data=train,ax=ax[1])
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %%
We observe that Pclass1 were survived more than 2,3.
Also among males & females,females were survived more than males.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.8f) Create Bar(count) plot for checking the Embarked vs (No. of passengers, sex, Survived , Pclass). And your Observations?

# %%
# create subplot plot
f,ax=plt.subplots(2,2,figsize=(20,9))
# create Bar (count) plot for Embarked vs. No. Of Passengers Boarded
sns.barplot(x=train['Embarked'],y=train['PassengerId'],ax=ax[0,0])
ax[0,0].set_title('Embarked vs. No. Of Passengers Boarded')
# create Bar (count) plot for Embarked vs. Male-Female Split
sns.countplot(hue=train['Sex'],x=train['Embarked'],ax=ax[0,1])
ax[0,1].set_title('Embarked vs. Male-Female Split')
# create Bar (count) plot for Embarked vs Survived
sns.countplot(x=train['Embarked'],hue=train['Survived'],ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
# create Bar (count) plot for Embarked vs Pclass
sns.countplot(x=train['Embarked'],hue=train['Pclass'],ax=ax[1,1])
ax[1,1].set_title(' Embarked vs Pclass')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %%
We can observe here that most passengers embarked were from Southampton.
Also most male & females were from Southampton.
Most numbers of deaths were for people embarked from Southampton only.
Lastly we can also see that the Southampton had highest number of Class-3 passengers.
Most Class-1 passengers were embarked from C.

# %% [markdown]
# ### Box Plot
# A box plot or boxplot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">1.8 g)Create a box plot for pclass vs Age. And your Observations?

# %%
plt.subplots(figsize=(5,5))
sns.boxplot(x=train['Pclass'],y=train['Age'])
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %%
We can see that Class-1 has the highest mean age among all the classes followed by 2,3.
This implies more young people belonged to the Class-3 and least belonged to Class-1.

Although we have outliers in Class-2 & 3,there is no such outliers in Class-1.
Even median age of the classes are in the Order-1>2>3.

Hence in EDA process,Class-2,3 outliers will be more important to be removed.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.9 Categorical vs. Categorical
#
# * Categorical:

# %% [markdown]
# ### Stacked bar chart

# %% [markdown]
# A stacked bar chart, also known as a stacked bar graph, is a graph that is used to break down and compare parts of a whole. Each bar in the chart represents a whole, and segments in the bar represent different parts or categories of that whole. Different colors are used to illustrate the different categories in the bar.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.9a) Create a Stacked bar chart Sex Vs Survived. And your Observations?

# %%
#create crosstab
pd.pivot_table(data=train,index=['Sex'],columns='Survived',values='PassengerId',aggfunc='count').plot(kind='bar',stacked=True)
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %%
We can clearly observe that Survival rate in Females are much more than their male counterparts.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.10 Quantitative vs. Quantitative

# %% [markdown]
#     Numerical Features:

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  1.10a) Create a scatter plot for showing age & fare with target varialble. And your Observations?¶

# %%
sns.scatterplot(x=train['Age'],y=train['Fare'],hue=train['Survived'])
plt.title('Age & Fare Wrt Survived')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#aec101"> Observation:

# %%
We can clearly see that people who had fare below 100 are the ones who did not survive.
So people with high fares managed to survive more as per the graph.
Clearly outliers are there but above observation fits most of the datapoints.

W.r.t. age,we can see that almost all age group people had died especially above 30.
Only outlier here is a survivor of 80 age.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.11 Frequency tables

# %% [markdown]
# 1. One-Way Tables
# 2. Two-Way Tables

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.11 a) Create frequency tables (also known as crosstabs) in pandas using the pd.crosstab() function.

# %%
 # Make a crosstab
one_way=pd.crosstab(index=train['Survived'],columns='count')
# Name the count column
one_way
# Out:
# col_0     count
# Survived
# 0           549
# 1           342

# %% [markdown]
# #### Two-Way Tables
#
# Two-way frequency tables, also called contingency tables, are tables of counts with two dimensions where each dimension is a different variable. Two-way tables can give you insight into the relationship between two variables.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">1.11b )Create Two-way-table for survival vs sex?

# %%
two_way=pd.crosstab(index=train['Survived'],columns=train['Sex'])
two_way.index=['Died','Survived']
two_way
# Out:
# Sex       female  male
# Died          81   468
# Survived     233   109

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.12 Check Correlation plot using Headtmap?

# %%
plt.subplots(figsize=(15,5))
sns.heatmap(train.corr(),annot=True)
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#aec101"> Observation:

# %%
1)Survival is related to Pclass with negative correlation ~.34 and Fare with positive correlation ~.26
2)Pclass is related most to Fare with negative correlation >.5 and also to Age with negative correlation ~.37
3)Parch and SibSp have moderate correlation ~.41

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.12 a) Check the pairplot?

# %%
## Pairplot wrt target variable
sns.pairplot(data=train,hue='Survived')
plt.show()
# Out:
# C:\Users\AVIRAJ\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\AVIRAJ\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\AVIRAJ\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\AVIRAJ\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#aec101"> Observation:

# %%
We can see various types of correlations in the dataset.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.13 Read the AirPassengers dataset and plot the Seasonality.And your observations?

# %%
air=pd.read_csv('C:\\Users\\AVIRAJ\\Downloads\\AirPassengers.csv',parse_dates=['Month'], index_col='Month')

#Parse strings to datetime type

#convert from string to datetime
air.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
plt.subplots(figsize=(7,5))
plt.plot(air['#Passengers'])
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

plt.figure(figsize=(15,8))

plt.plot(seasonal_decompose(air.apply(np.log)).seasonal)

plt.xlabel('Seasonality of Air Passengers from 1949 to 1969')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101">Observations:

# %%
The pattern of data is repititive for each year

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:##e08484"> THE END
